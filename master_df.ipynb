# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
master_df_2011 = pd.read_csv(r'C:/Users/A629107/Downloads/2011_BCP_ALL_for_WA_short-header/2011 Census BCP All Geographies for WA/POA/WA/2011Census_B01_WA_POA_short.csv', usecols = ['region_id'])
master_df_2011 = pd.DataFrame(master_df_2011)
master_df_2011.head()
# Out:
#   region_id
# 0   POA6000
# 1   POA6003
# 2   POA6004
# 3   POA6005
# 4   POA6006

# %%
poa_area = pd.read_excel(r'C:\Users\A629107\Downloads\2011_BCP_ALL_for_WA_short-header\Metadata\2011Census_geog_desc_1st_2nd_3rd_release.xlsx', sheet_name = 0)
poa_area = pd.DataFrame(poa_area[poa_area['Level'] == 'POA'])
poa_area.head()
# Out:
#      Level     Code     Label     Area sqkm
# 2382   POA  POA0800  0800, NT       3.12306
# 2383   POA  POA0810  0810, NT      24.42860
# 2384   POA  POA0812  0812, NT      35.88990
# 2385   POA  POA0820  0820, NT      39.05170
# 2386   POA  POA0822  0822, NT  144468.87000

# %%
master_df_2011 = master_df_2011.merge(poa_area, left_on = 'region_id', right_on = 'Code', how = 'inner')
master_df_2011 = master_df_2011.iloc[:,[0,4]]
master_df_2011.head()
# Out:
#   region_id  Area sqkm
# 0   POA6000   8.754390
# 1   POA6003   0.839059
# 2   POA6004   3.315890
# 3   POA6005   2.189270
# 4   POA6006   3.089980

# %%
master_df_2011.columns = ["POA", "Area"]

# %%
age_groups = pd.read_csv(r'C:\Users\A629107\Downloads\2011_BCP_ALL_for_WA_short-header\2011 Census BCP All Geographies for WA\POA\WA\2011Census_B01_WA_POA_short.csv')
age_groups = pd.DataFrame(age_groups)
master_df_2011 = master_df_2011.merge(age_groups, left_on = 'POA', right_on = 'region_id', how = 'inner')
master_df_2011.head()
# Out:
#        POA      Area region_id  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  \
# 0  POA6000  8.754390   POA6000     5227     4010     9237           148
# 1  POA6003  0.839059   POA6003     1613     1340     2953            46
# 2  POA6004  3.315890   POA6004     4474     3710     8184           161
# 3  POA6005  2.189270   POA6005     2777     2391     5168            75
# 4  POA6006  3.089980   POA6006     4219     4325     8544           298
#
#    Age_0_4_yr_F  Age_0_4_yr_P  Age_5_14_yr_M             ...              \
# 0           159           307            145             ...
# 1            42            88             68             ...
# 2           113           274            116             ...
# 3            75           150             82             ...
# 4           272           570            414             ...
#
#    High_yr_schl_comp_Yr_8_belw_P  High_yr_schl_comp_D_n_g_sch_M  \
# 0                            212                             35
# ...

# %%
master_df_2011 = master_df_2011.drop(master_df_2011.columns[39:], axis=1)

# %%
master_df_2011 = master_df_2011.drop('region_id', axis =1)

# %%
master_df_2011
# Out:
#          POA           Area  Tot_P_M  Tot_P_F  Tot_P_P  Age_0_4_yr_M  \
# 0    POA6000       8.754390     5227     4010     9237           148
# 1    POA6003       0.839059     1613     1340     2953            46
# 2    POA6004       3.315890     4474     3710     8184           161
# 3    POA6005       2.189270     2777     2391     5168            75
# 4    POA6006       3.089980     4219     4325     8544           298
# 5    POA6007       2.841030     3292     3455     6747           198
# 6    POA6008       7.086160     6761     7097    13858           382
# 7    POA6009       8.714000     8075     8496    16571           373
# 8    POA6010      15.572800     7489     7992    15481           413
# 9    POA6011       4.818430     4297     4628     8925           214
# 10   POA6012       4.347390     3943     4655     8598           198
# 11   POA6014       9.580700     9327     9657    18984           643
# 12   POA6015       9.807360     3122     3232     6354           132
# ...

# %%
master_df_2011.plot.bar(x = "POA", y = "Tot_P_M", figsize =(100,10))
