# %%
import numpy as np
import pandas as pd

# %%
product_name = np.random.choice(['Moto G6', 'Apple iPhone 6', 'Honor 7X', 'BLU Studio X8', 'Moto E (4th Generation)', 'Moto G PLUS', 'Nokia 6.1', 'Lg Vn170', 'Moto X (4th Generation)', 'Apple iPhone', 'Samsung Galaxy S9+'], 1000, p=[0.01, 0.09, 0.04, 0.06, 0.2, 0.1 ,0.1, 0.04, 0.06, 0.2, 0.1])
shipping_type = np.random.choice(['Free', 'Customer Paid'], 1000, p=[0.7,0.3])
customer_type = np.random.choice(['New', 'Existing'], 1000, p=[0.2,0.8])
customer_type
# Out:
# array(['Existing', 'Existing', 'Existing', 'Existing', 'New', 'New',
#        'Existing', 'New', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'New', 'New', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'New', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'New', 'New',
#        'Existing', 'New', 'New', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'New', 'New', 'New', 'Existing', 'New',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'New', 'New', 'Existing', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'New', 'Existing', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'New', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing', 'New',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'New', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'New', 'Existing',
#        'New', 'Existing', 'New', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'New', 'Existing',
#        'Existing', 'New', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'New', 'Existing', 'New',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'Existing', 'Existing',
#        'New', 'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'New', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'New', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'New', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'New', 'New', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'New', 'New',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'Existing', 'Existing',
#        'Existing', 'Existing', 'Existing', 'New', 'Existing'],
#       dtype='<U8')
